# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
wisconsin = pd.read_csv('C:/Users/Mahesh/wisconsin.csv', index_col = 0)
wisconsin.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
data = wisconsin['texture_mean'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('Wisconsin')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
cars_data = pd.read_csv('C:/Users/Mahesh/wisconsin.csv', index_col = 0, na_values = ['??', '????'])
cars_data.size
# Out:
# 18208

# %%
cars_data = pd.read_csv('C:/Users/Mahesh/wisconsin.csv', index_col = 0)
cars_data.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  texture_worst  \
# id                                            ...
# ...

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = cars_data['texture_mean'], y = cars_data['perimeter_mean'])
# Out:
# <AxesSubplot:xlabel='texture_mean', ylabel='perimeter_mean'>

# %%
sns.regplot(x = cars_data['texture_mean'], y = cars_data['perimeter_mean'], fit_reg = False)
# Out:
# <AxesSubplot:xlabel='texture_mean', ylabel='perimeter_mean'>

# %%
sns.lmplot(x = 'texture_mean', y = 'area_mean', data = cars_data, fit_reg = False, hue = 'diagnosis',
           legend = True, palette = 'Set1')

# %%
sns.distplot(cars_data['area_mean'])
# Out:
# C:\Users\Mahesh\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='area_mean', ylabel='Density'>

# %%
sns.distplot(cars_data['area_mean'], kde = False, bins = 5)
# Out:
# C:\Users\Merin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='area_mean'>

# %%
sns.countplot(x = 'diagnosis', data = cars_data)
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='count'>

# %%
sns.boxplot(x = cars_data['diagnosis'], y = cars_data['area_mean'])
# Out:
# <AxesSubplot:xlabel='diagnosis', ylabel='area_mean'>
